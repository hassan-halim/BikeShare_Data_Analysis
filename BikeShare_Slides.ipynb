# %% [markdown]
# # Ford GoBike System Data

# %% [markdown]
# # 1- Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import seaborn as sb

# %matplotlib inline

# %%
# Read the dataset abd printout head
df = pd.read_csv('201902-fordgobike-tripdata.csv')
df.head(3)
# Out:
#    duration_sec                start_time                  end_time  \
# 0         52185  2019-02-28 17:32:10.1450  2019-03-01 08:01:55.9750
# 1         42521  2019-02-28 18:53:21.7890  2019-03-01 06:42:03.0560
# 2         61854  2019-02-28 12:13:13.2180  2019-03-01 05:24:08.1460
#
#    start_station_id                                start_station_name  \
# 0              21.0  Montgomery St BART Station (Market St at 2nd St)
# 1              23.0                     The Embarcadero at Steuart St
# 2              86.0                           Market St at Dolores St
#
#    start_station_latitude  start_station_longitude  end_station_id  \
# 0               37.789625              -122.400811            13.0
# 1               37.791464              -122.391034            81.0
# 2               37.769305              -122.426826             3.0
#
#                                end_station_name  end_station_latitude  \
# 0                Commercial St at Montgomery St             37.794231
# 1                            Berry St at 4th St             37.775880
# 2  Powell St BART Station (Market St at 4th St)             37.786375
#
#    end_station_longitude  bike_id user_type  member_birth_year member_gender  \
# 0            -122.402923     4902  Customer             1984.0          Male
# 1            -122.393170     2535  Customer                NaN           NaN
# 2            -122.404904     5905  Customer             1972.0          Male
#
#   bike_share_for_all_trip
# 0                      No
# 1                      No
# 2                      No

# %%
print ('There are {0} features, and {1} Observations in the dataset'.format(df.shape[1], df.shape[0]))
# Out:
# There are 16 features, and 183412 Observations in the dataset

# %% [markdown]
# ## 1.1 Check for Null Values

# %%
df.info(null_counts = 1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183412 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             183412 non-null  int64
#  1   start_time               183412 non-null  object
#  2   end_time                 183412 non-null  object
#  3   start_station_id         183215 non-null  float64
#  4   start_station_name       183215 non-null  object
#  5   start_station_latitude   183412 non-null  float64
#  6   start_station_longitude  183412 non-null  float64
#  7   end_station_id           183215 non-null  float64
#  8   end_station_name         183215 non-null  object
#  9   end_station_latitude     183412 non-null  float64
#  10  end_station_longitude    183412 non-null  float64
#  11  bike_id                  183412 non-null  int64
#  12  user_type                183412 non-null  object
#  13  member_birth_year        175147 non-null  float64
#  14  member_gender            175147 non-null  object
#  15  bike_share_for_all_trip  183412 non-null  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.4+ MB

# %%
df.isnull().any()
# Out:
# duration_sec               False
# start_time                 False
# end_time                   False
# start_station_id            True
# start_station_name          True
# start_station_latitude     False
# start_station_longitude    False
# end_station_id              True
# end_station_name            True
# end_station_latitude       False
# end_station_longitude      False
# bike_id                    False
# user_type                  False
# member_birth_year           True
# member_gender               True
# bike_share_for_all_trip    False
# dtype: bool

# %%
df_nulls = df[df.isnull().any(axis=1)]
df_nulls.shape
# Out:
# (8460, 16)

# %%
# Drop null values and create new dataset
df2 = df.dropna()

# %%
df2.info(null_counts = True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174952 non-null  int64
#  1   start_time               174952 non-null  object
#  2   end_time                 174952 non-null  object
#  3   start_station_id         174952 non-null  float64
#  4   start_station_name       174952 non-null  object
#  5   start_station_latitude   174952 non-null  float64
#  6   start_station_longitude  174952 non-null  float64
#  7   end_station_id           174952 non-null  float64
#  8   end_station_name         174952 non-null  object
#  9   end_station_latitude     174952 non-null  float64
#  10  end_station_longitude    174952 non-null  float64
#  11  bike_id                  174952 non-null  int64
#  12  user_type                174952 non-null  object
#  13  member_birth_year        174952 non-null  float64
#  14  member_gender            174952 non-null  object
#  15  bike_share_for_all_trip  174952 non-null  object
# dtypes: float64(7), int64(2), object(7)
# memory usage: 22.7+ MB

# %% [markdown]
# Lets Fix the data types of some columns

# %%
df2.start_station_id = df2.start_station_id.astype(int)
df2.end_station_id = df2.end_station_id.astype(int)
df2.user_type  = df2.user_type.astype('category')
df2.member_gender  = df2.member_gender.astype('category')
df2.start_time = pd.to_datetime(df2.start_time)
df2.end_time = pd.to_datetime(df2.end_time)
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 174952 entries, 0 to 183411
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   duration_sec             174952 non-null  int64
#  1   start_time               174952 non-null  datetime64[ns]
#  2   end_time                 174952 non-null  datetime64[ns]
#  3   start_station_id         174952 non-null  int64
#  4   start_station_name       174952 non-null  object
#  5   start_station_latitude   174952 non-null  float64
#  6   start_station_longitude  174952 non-null  float64
#  7   end_station_id           174952 non-null  int64
#  8   end_station_name         174952 non-null  object
#  9   end_station_latitude     174952 non-null  float64
#  10  end_station_longitude    174952 non-null  float64
#  11  bike_id                  174952 non-null  int64
#  12  user_type                174952 non-null  category
#  13  member_birth_year        174952 non-null  float64
#  14  member_gender            174952 non-null  category
#  15  bike_share_for_all_trip  174952 non-null  object
# dtypes: category(2), datetime64[ns](2), float64(5), int64(4), object(3)
# memory usage: 20.4+ MB
# /home/hhalim/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5168: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[name] = value

# %% [markdown]
# 8460 Rows have missing values in columns member_birth_year, and member_gender

# %% [markdown]
# ## 1.2 Check for Duplicated values

# %%
df2.duplicated().any()
#no duplicated values which is good
# Out:
# False

# %% [markdown]
# ## 1.3 Know more about the dataset

# %%
# Frequency tables for each categorical feature
for column in df2.select_dtypes(include=['object', 'category']).columns:
    display(pd.crosstab(index=df2[column], columns='% observations', normalize='columns')*100)
# Out:
# col_0                                               % observations
# start_station_name
# 10th Ave at E 15th St                                     0.031437
# 10th St at Fallon St                                      0.197197
# 10th St at University Ave                                 0.106886
# 11th St at Bryant St                                      0.452696
# 11th St at Natoma St                                      0.459555
# ...                                                            ...
# Williams Ave at 3rd St                                    0.027436
# Williams Ave at Apollo St                                 0.014290
# Willow St at Vine St                                      0.005144
# Woolsey St at Sacramento St                               0.197197
# Yerba Buena Center for the Arts (Howard St at 3...        0.454410
#
# [329 rows x 1 columns]
# col_0                                               % observations
# end_station_name
# 10th Ave at E 15th St                                     0.020005
# 10th St at Fallon St                                      0.205199
# 10th St at University Ave                                 0.156043
# 11th St at Bryant St                                      0.540720
# 11th St at Natoma St                                      0.479560
# ...                                                            ...
# Williams Ave at 3rd St                                    0.028579
# Williams Ave at Apollo St                                 0.011432
# Willow St at Vine St                                      0.002858
# Woolsey St at Sacramento St                               0.196054
# Yerba Buena Center for the Arts (Howard St at 3...        0.475559
#
# [329 rows x 1 columns]
# col_0       % observations
# user_type
# Customer          9.468883
# Subscriber       90.531117
# col_0          % observations
# member_gender
# Female              23.323540
# Male                74.591888
# Other                2.084572
# col_0                    % observations
# bike_share_for_all_trip
# No                            90.085281
# Yes                            9.914719

# %%
# Start Stations and End stations 
display(df2.describe(include=np.object))
# Out:
#           start_station_name  \
# count                 174952
# unique                   329
# top     Market St at 10th St
# freq                    3649
#
#                                          end_station_name  \
# count                                              174952
# unique                                                329
# top     San Francisco Caltrain Station 2  (Townsend St...
# freq                                                 4624
#
#        bike_share_for_all_trip
# count                   174952
# unique                       2
# top                         No
# freq                    157606

# %%
#a sample dataset where start_station repeated more than 1000 times
df_sample = df2.groupby("start_station_name").filter(lambda x: len(x) > 1000)
df_sample.shape
df_sample
# Out:
#         duration_sec              start_time                end_time  \
# 0              52185 2019-02-28 17:32:10.145 2019-03-01 08:01:55.975
# 5               1793 2019-02-28 23:49:58.632 2019-03-01 00:19:51.760
# 9               1049 2019-02-28 23:49:47.699 2019-03-01 00:07:17.025
# 11               506 2019-02-28 23:56:55.540 2019-03-01 00:05:21.733
# 14               395 2019-02-28 23:56:26.848 2019-03-01 00:03:01.947
# ...              ...                     ...                     ...
# 183403           249 2019-02-01 00:15:12.067 2019-02-01 00:19:21.699
# 183405           111 2019-02-01 00:14:49.874 2019-02-01 00:16:41.301
# 183407           480 2019-02-01 00:04:49.724 2019-02-01 00:12:50.034
# 183408           313 2019-02-01 00:05:34.744 2019-02-01 00:10:48.502
# 183411           271 2019-02-01 00:00:20.636 2019-02-01 00:04:52.058
#
#         start_station_id                                 start_station_name  \
# 0                     21   Montgomery St BART Station (Market St at 2nd St)
# 5                     93                       4th St at Mission Bay Blvd S
# 9                     19                               Post St at Kearny St
# 11                    44  Civic Center/UN Plaza BART Station (Market St ...
# 14                   243                        Bancroft Way at College Ave
# ...                  ...                                                ...
# 183403               256                           Hearst Ave at Euclid Ave
# 183405               324                Union Square (Powell St at Post St)
# 183407                27                            Beale St at Harrison St
# 183408                21   Montgomery St BART Station (Market St at 2nd St)
# 183411                24                              Spear St at Folsom St
#
#         start_station_latitude  start_station_longitude  end_station_id  \
# 0                    37.789625              -122.400811              13
# 5                    37.770407              -122.391198             323
# 9                    37.788975              -122.403452             121
# 11                   37.781074              -122.411738             343
# 14                   37.869360              -122.254337             252
# ...                        ...                      ...             ...
# 183403               37.875112              -122.260553             247
# 183405               37.788300              -122.408531              19
# 183407               37.788059              -122.391865             324
# 183408               37.789625              -122.400811              66
# 183411               37.789677              -122.390428              37
#
#                            end_station_name  end_station_latitude  \
# 0            Commercial St at Montgomery St             37.794231
# 5                        Broadway at Kearny             37.798014
# 9                        Mission Playground             37.759210
# 11                      Bryant St at 2nd St             37.783172
# 14             Channing Way at Shattuck Ave             37.865847
# ...                                     ...                   ...
# 183403            Fulton St at Bancroft Way             37.867789
# 183405                 Post St at Kearny St             37.788975
# 183407  Union Square (Powell St at Post St)             37.788300
# 183408                3rd St at Townsend St             37.778742
# 183411                  2nd St at Folsom St             37.785000
#
#         end_station_longitude  bike_id   user_type  member_birth_year  \
# 0                 -122.402923     4902    Customer             1984.0
# 5                 -122.405950     5200  Subscriber             1959.0
# 9                 -122.421339     6488  Subscriber             1992.0
# 11                -122.393572     5848  Subscriber             1993.0
# 14                -122.267443     4786  Subscriber             1988.0
# ...                       ...      ...         ...                ...
# 183403            -122.265896     4642  Subscriber             2000.0
# 183405            -122.403452     4832  Subscriber             1984.0
# 183407            -122.408531     4832  Subscriber             1996.0
# 183408            -122.392741     4960  Subscriber             1984.0
# 183411            -122.395936     1057  Subscriber             1989.0
#
#        member_gender bike_share_for_all_trip
# 0               Male                      No
# 5               Male                      No
# 9               Male                      No
# 11              Male                      No
# 14              Male                      No
# ...              ...                     ...
# 183403          Male                      No
# 183405          Male                      No
# 183407          Male                      No
# 183408          Male                      No
# 183411          Male                      No
#
# [64959 rows x 16 columns]

# %%
print("We have {0} Start Stations, and {1} End Stations"
      .format(len(df2.start_station_id.unique()), len(df2.end_station_id.unique())))
print("Number of unique bikes: {0}".format(len(df2.bike_id.unique())))
# Out:
# We have 329 Start Stations, and 329 End Stations
# Number of unique bikes: 4607

# %% [markdown]
# # 2. Data Analysis

# %% [markdown]
# ## 2.1 Univariate Analysis

# %% [markdown]
# ### Duration in Seconds & Minutes

# %%
df2.duration_sec.describe()
# Out:
# count    174952.000000
# mean        704.002744
# std        1642.204905
# min          61.000000
# 25%         323.000000
# 50%         510.000000
# 75%         789.000000
# max       84548.000000
# Name: duration_sec, dtype: float64

# %%
df2['duration_min'] = df2.duration_sec / 60
# Out:
# <ipython-input-16-365930379025>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['duration_min'] = df2.duration_sec / 60

# %%
# Duration of the bike rides
bin_edges = np.arange(0, 3600, 60)

plt.hist(data = df2, x = 'duration_sec', bins = bin_edges, rwidth = 0.6);

plt.title("Trip Duration in Seconds", fontsize=16, fontweight='bold')
plt.xlabel('Duration (Sec)')
plt.ylabel('Number of Trips');

# %% [markdown]
# We could also show the distribution of the duration in minutes

# %%
bin_edges = bin_edges = np.arange(0, 45, 1)
plt.hist(data = df2, x = 'duration_min', bins = bin_edges, rwidth = 0.6);
ticks = [0, 5, 10, 15, 20, 25, 30,  35, 40, 45, 50, 55, 60]
plt.xticks(ticks)
plt.title("Trip Duration in Minutes", fontsize=16, fontweight='bold')
plt.xlabel('Duration (Minutes)')
plt.ylabel('Number of Trips');

# %%
df2.duration_min.describe()
# Out:
# count    174952.000000
# mean         11.733379
# std          27.370082
# min           1.016667
# 25%           5.383333
# 50%           8.500000
# 75%          13.150000
# max        1409.133333
# Name: duration_min, dtype: float64

# %%
df2.duration_min.quantile([.1, .25, .5, .75, .95, .99])
# Out:
# 0.10     3.550000
# 0.25     5.383333
# 0.50     8.500000
# 0.75    13.150000
# 0.95    25.516667
# 0.99    52.933333
# Name: duration_min, dtype: float64

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> As shown above, 95% of the data have average tripe time less than 26 minutes, 99% with average trip time less than 53 minutes. While in general the average trip time is about 12 minutes. We still have some extreme values in column (duration_min) but moving forward we focus only with rows that have average trip time less than 60m.

# %% [markdown]
# ### User Types

# %%
# user type
df2.user_type.unique()
useTypeCounts = df2.user_type.value_counts()
p, tx, autotexts = plt.pie(useTypeCounts, labels=useTypeCounts.index,startangle = 90, counterclock=False, autopct='')

for i, a in enumerate(autotexts):
    a.set_text("{}".format(useTypeCounts[i]))
plt.axis('square')
plt.xlabel('{0:.2f}% of data are for Subscribers, {1:.2f}% is the proportion of Customers'.
           format(
               (useTypeCounts[0] / df.shape[0] * 100),
               (useTypeCounts[1] / df.shape[0] * 100)))
# Out:
# Text(0.5, 0, '86.36% of data are for Subscribers, 9.03% is the proportion of Customers')

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> Most of our users are subscribers 86.36%, Customers shares is 9.03%.

# %% [markdown]
# ### User Gender

# %%
# user type
df2.member_gender.unique()
genderCounts = df2.member_gender.value_counts()
p, tx, autotexts = plt.pie(genderCounts, labels=genderCounts.index,startangle = 90, counterclock=False, autopct='')

for i, a in enumerate(autotexts):
    a.set_text("{}".format(genderCounts[i]))
plt.axis('square')
plt.xlabel('{0:.2f}% of our Travellers are males, {1:.2f}% is the proportion of Female riders'.
           format(
               (genderCounts[0] / df.shape[0] * 100),
               (genderCounts[1] / df.shape[0] * 100)))
# Out:
# Text(0.5, 0, '71.15% of our Travellers are males, 22.25% is the proportion of Female riders')

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> Most of our users are Males 71.15%, Female riders represents 22.25% of the dataset.

# %% [markdown]
# ### When are most trips taken in terms of time of day, day of the week, or month of the year

# %% [markdown]
# #### Month of The Year

# %% [markdown]
# As it shown in the below, all the records are in February, no distrubtion by month of the year is relevant here

# %%
df2.groupby(df2['start_time'].dt.month.astype(int)).count()
# Out:
#             duration_sec  start_time  end_time  start_station_id  \
# start_time
# 2                 174952      174952    174952            174952
#
#             start_station_name  start_station_latitude  \
# start_time
# 2                       174952                  174952
#
#             start_station_longitude  end_station_id  end_station_name  \
# start_time
# 2                            174952          174952            174952
#
#             end_station_latitude  end_station_longitude  bike_id  user_type  \
# start_time
# 2                         174952                 174952   174952     174952
#
#             member_birth_year  member_gender  bike_share_for_all_trip  \
# start_time
# 2                      174952         174952                   174952
#
#             duration_min
# start_time
# 2                 174952

# %% [markdown]
# #### Day of a Month

# %%
plt.figure(figsize=[20, 5])
start_times = df2.groupby(df2['start_time'].dt.day).count().start_time
plt.bar(start_times.index, start_times)
plt.xticks(start_times.index, rotation=90)
plt.xlabel('')
plt.title("Distribution of trips over Days of The Month", fontsize=16, fontweight='bold')
plt.xlabel('Days of the Month')
plt.ylabel('Number of Trips');

# %% [markdown]
# #### Weekday

# %%
start_times = df2.groupby(df2['start_time'].dt.weekday).count().start_time
days_of_the_week = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
plt.bar(days_of_the_week, start_times)
plt.xticks(days_of_the_week, rotation=90)
plt.title("Distribution of trips by Weekdays", fontsize=16, fontweight='bold')
plt.xlabel('Weekdays')
plt.ylabel('Number of Trips');

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> As hown above, weekends are have the lowest shares every week

# %% [markdown]
# #### Day Hours

# %%
plt.figure(figsize=[20, 5])
start_times = df2.groupby(df2['start_time'].dt.hour).count().start_time
plt.bar(start_times.index, start_times)
plt.xticks(start_times.index, rotation=90)
plt.xlabel('Distribution of shares over hours of the day')
plt.title("Distribution of trips by day hours", fontsize=16, fontweight='bold')
plt.xlabel('Day Hours')
plt.ylabel('Number of Trips');

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> Morning (7-9 AM) and evening (3-7 PM) rush hours have more data than other hours of the day

# %% [markdown]
# ## User Age

# %%
# Use member_birth_year to draw the user's age distribution.
#add column for user age to be used in bivariate analysis
df2['age_years'] = 2019 - df2.member_birth_year

binsize = 1
bins = np.arange(0, df2['member_birth_year'].astype(float).max()+binsize, binsize)

plt.figure(figsize=[8, 5])
plt.hist(data = df2, x = 'age_years', bins = bins)
plt.axis([10, 80, 0, 12000])
plt.title('The Distribution of User Age', fontsize=16, fontweight='bold')
plt.xlabel('Age')
plt.ylabel('Number of Users')
# Out:
# <ipython-input-49-858c16a350ce>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df2['age_years'] = 2019 - df2.member_birth_year
# Text(0, 0.5, 'Number of Users')

# %%
df2.age_years.quantile([.10, .2, .5,.75, .9, .95, .99])
# Out:
# 0.10    24.0
# 0.20    26.0
# 0.50    32.0
# 0.75    39.0
# 0.90    49.0
# 0.95    55.0
# 0.99    64.0
# Name: age_years, dtype: float64

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> Most of our users are under Age 60 (95%) and 99% of users are under ager 65.

# %% [markdown]
# ## 2.1 Bivariate Analysis

# %%
display(df2.corr())
pd.plotting.scatter_matrix(df2, figsize=(12, 12))
# Out:
#                          duration_sec  start_station_id  \
# duration_sec                 1.000000         -0.006876
# start_station_id            -0.006876          1.000000
# start_station_latitude       0.012237         -0.195403
# start_station_longitude     -0.040946          0.465130
# end_station_id               0.002552          0.339914
# end_station_latitude         0.012854         -0.184317
# end_station_longitude       -0.041438          0.472373
# bike_id                      0.011037         -0.068114
# member_birth_year           -0.006041          0.115115
# duration_min                 1.000000         -0.006876
# age_years                    0.006041         -0.115115
#
#                          start_station_latitude  start_station_longitude  \
# duration_sec                           0.012237                -0.040946
# start_station_id                      -0.195403                 0.465130
# start_station_latitude                 1.000000                -0.678105
# start_station_longitude               -0.678105                 1.000000
# end_station_id                        -0.184497                 0.485894
# end_station_latitude                   0.990130                -0.682598
# end_station_longitude                 -0.683552                 0.992507
# bike_id                                0.051140                -0.144058
# member_birth_year                     -0.075238                 0.125346
# duration_min                           0.012237                -0.040946
# age_years                              0.075238                -0.125346
#
#                          end_station_id  end_station_latitude  \
# duration_sec                   0.002552              0.012854
# start_station_id               0.339914             -0.184317
# start_station_latitude        -0.184497              0.990130
# start_station_longitude        0.485894             -0.682598
# end_station_id                 1.000000             -0.202501
# end_station_latitude          -0.202501              1.000000
# end_station_longitude          0.475503             -0.685085
# bike_id                       -0.056796              0.050507
# member_birth_year              0.112709             -0.075339
# duration_min                   0.002552              0.012854
# age_years                     -0.112709              0.075339
#
#                          end_station_longitude   bike_id  member_birth_year  \
# duration_sec                         -0.041438  0.011037          -0.006041
# start_station_id                      0.472373 -0.068114           0.115115
# start_station_latitude               -0.683552  0.051140          -0.075238
# start_station_longitude               0.992507 -0.144058           0.125346
# end_station_id                        0.475503 -0.056796           0.112709
# end_station_latitude                 -0.685085  0.050507          -0.075339
# end_station_longitude                 1.000000 -0.145895           0.126191
# bike_id                              -0.145895  1.000000           0.036226
# member_birth_year                     0.126191  0.036226           1.000000
# duration_min                         -0.041438  0.011037          -0.006041
# age_years                            -0.126191 -0.036226          -1.000000
#
#                          duration_min  age_years
# duration_sec                 1.000000   0.006041
# start_station_id            -0.006876  -0.115115
# start_station_latitude       0.012237   0.075238
# start_station_longitude     -0.040946  -0.125346
# end_station_id               0.002552  -0.112709
# end_station_latitude         0.012854   0.075339
# end_station_longitude       -0.041438  -0.126191
# bike_id                      0.011037  -0.036226
# member_birth_year           -0.006041  -1.000000
# duration_min                 1.000000   0.006041
# age_years                    0.006041   1.000000
# array([[<AxesSubplot:xlabel='duration_sec', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='duration_sec'>,
#         <AxesSubplot:xlabel='age_years', ylabel='duration_sec'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='start_station_id'>,
#         <AxesSubplot:xlabel='age_years', ylabel='start_station_id'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='start_station_latitude'>,
#         <AxesSubplot:xlabel='age_years', ylabel='start_station_latitude'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='start_station_longitude'>,
#         <AxesSubplot:xlabel='age_years', ylabel='start_station_longitude'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='end_station_id'>,
#         <AxesSubplot:xlabel='age_years', ylabel='end_station_id'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='end_station_latitude'>,
#         <AxesSubplot:xlabel='age_years', ylabel='end_station_latitude'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='end_station_longitude'>,
#         <AxesSubplot:xlabel='age_years', ylabel='end_station_longitude'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='bike_id'>,
#         <AxesSubplot:xlabel='age_years', ylabel='bike_id'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='member_birth_year'>,
#         <AxesSubplot:xlabel='age_years', ylabel='member_birth_year'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='duration_min'>,
#         <AxesSubplot:xlabel='age_years', ylabel='duration_min'>],
#        [<AxesSubplot:xlabel='duration_sec', ylabel='age_years'>,
#         <AxesSubplot:xlabel='start_station_id', ylabel='age_years'>,
#         <AxesSubplot:xlabel='start_station_latitude', ylabel='age_years'>,
#         <AxesSubplot:xlabel='start_station_longitude', ylabel='age_years'>,
#         <AxesSubplot:xlabel='end_station_id', ylabel='age_years'>,
#         <AxesSubplot:xlabel='end_station_latitude', ylabel='age_years'>,
#         <AxesSubplot:xlabel='end_station_longitude', ylabel='age_years'>,
#         <AxesSubplot:xlabel='bike_id', ylabel='age_years'>,
#         <AxesSubplot:xlabel='member_birth_year', ylabel='age_years'>,
#         <AxesSubplot:xlabel='duration_min', ylabel='age_years'>,
#         <AxesSubplot:xlabel='age_years', ylabel='age_years'>]],
#       dtype=object)

# %%
sb.set(style="whitegrid", context="notebook")
sb.pairplot(df2[["duration_min", "start_station_id",
                        "end_station_id","member_birth_year"]])

# %%
corr = df2[["duration_min", "start_station_id",
                        "end_station_id","member_birth_year"]].corr()
corr
ax = sb.heatmap(corr, annot=True,)

# %% [markdown]
# ### Check if duration in minutes is related to the user Age

# %%
# as mentioned earlier we focus only on trips with duration in minutes less than 60m (avoid extreme values)
df3 = df2[df2.duration_min < 60] 
plt.figure(figsize=[14,5])
plt.subplot(1, 2, 1)
plt.scatter(df3.age_years, df3.duration_min, alpha = 0.25, marker = '.' )
plt.title('Trip Duration and Age', fontsize=16, fontweight='bold')
plt.xlabel('Age')
plt.ylabel('Duaration In Minutes')

plt.subplot(1, 2, 2)
bins_y  = np.arange(200, 1250+50, 50)
bins_x = np.arange(-5, 85+1, 10)
plt.hist2d(df3.age_years, df3.duration_min, cmap='viridis_r')
plt.colorbar();
#250-1250

# %%
plt.figure(figsize = [20, 5])
sb.regplot(data = df3, x = 'age_years', y = 'duration_min', truncate=False, x_jitter=0.3, scatter_kws={'alpha':1/20});
plt.title('The relationship between user age and trip duration in minutes', fontsize=16, fontweight='bold')
plt.xlabel('Age (Years)')
plt.ylabel('Trip Duration (Minutes)')
# Out:
# Text(0, 0.5, 'Trip Duration (Minutes)')

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> The trip duration in minutes is higher in age range (20-60).

# %% [markdown]
# ### Relation between trip duration and member gender

# %%
plt.figure(figsize = [10, 5])
base_color = sb.color_palette()[0]
sb.boxplot(data = df3, x = 'member_gender', y = 'duration_min', color = base_color)
#plt.ylim([-10, 2000])
plt.title('Trip Duration and Gender', fontsize=16, fontweight='bold')
plt.xlabel('Gender')
plt.ylabel('Duration In Minutes')
# Out:
# Text(0, 0.5, 'Duration In Minutes')

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> The trip duration in minutes for femal and other is higher than male users.

# %% [markdown]
# ## 2.3 Multivariate Exploration

# %%
markers = [['Male', 'v'],['Female', 's'],['Other', 'o']]

for gender, marker in markers:
    df_gender = df3[df3.member_gender == gender]
    plt.scatter(df_gender.age_years, df_gender.duration_min, marker = marker, alpha= 1)
plt.legend(['Male','Female','Other'])
plt.axis([10, 100, 0, 80 ])
plt.title('Trip Duration, Gender, and Age', fontsize=16, fontweight='bold')
plt.xlabel('Age')
plt.ylabel('Duration in Minutes')
# Out:
# Text(0, 0.5, 'Duration in Minutes')

# %%
# Duration (min) per user type and gender

graph = sb.catplot(data=df3, x='user_type', y="duration_min", hue="member_gender", kind="violin", height=5, aspect=2);

graph.set_axis_labels("User Type", "Trip Duration (Min)")
graph._legend.set_title('Gender')
graph.fig.suptitle('Trip Duration (Min) Per User Type and Gender', y=1.05, fontsize=16, fontweight='bold');

# %% [markdown]
# <font color='red' bold>__INSIGHT:__ </font> For Vustomer, and Subscribers, female users tend to have higher average trip time
